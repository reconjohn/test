# %% [markdown]
# # markdown cell (heading 1)
# ## second level heading
# - this is a list
#   - sublist
#   - $\sum_{i=1}^{N} 2^{-i} \approx 1$
#   - *italics*  **bold**

# %%
# this is a comment within a code cell
# it won't render like Markdown, but it won't get
# interpreted as python code either
print('hello world!')
# Out:
# hello world!

# %%
age = 42
first_name = 'Ahmed'

# %%
print('the age of', first_name, 'is', age)
# Out:
# the age of Ahmed is 42

# %%
print(last_name)
# Out:
# Best

# %%
last_name = "Best"
print(last_name)
# Out:
# Best

# %%
print(age)
future_age = age + 10
age = 43
print(future_age)
# Out:
# 42
# 52

# %%
# %whos
# Out:
# Variable     Type    Data/Info
# ------------------------------
# age          int     43
# first_name   str     Ahmed
# future_age   int     52
# last_name    str     Best

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E06D-15B2
#
#  Directory of C:\Users\Yohan_Min\Desktop\swc-python\demo
#
# 01/19/2019  01:27 AM    <DIR>          .
# 01/19/2019  01:27 AM    <DIR>          ..
# 01/19/2019  12:34 AM    <DIR>          .ipynb_checkpoints
# 01/19/2019  12:53 AM             6,419 afr_summary.csv
# 01/19/2019  12:52 AM             6,419 africa_summary.csv
# 01/18/2019  04:23 PM               746 summarize_data.py
# 01/19/2019  01:27 AM           323,606 swc_py_day1.ipynb
# 01/18/2019  07:16 PM           371,747 swc_py_day2.ipynb
#                5 File(s)        708,937 bytes
#                3 Dir(s)  352,529,854,464 bytes free

# %%
# %pwd
# Out:
# 'C:\\Users\\Yohan_Min\\Desktop\\swc-python\\demo'

# %% [markdown]
# # indexing strings

# %%
print(first_name)
# Out:
# Ahmed

# %%
print(first_name[0])
# Out:
# A

# %%
print(first_name[0:2])
# Out:
# Ah

# %%
print(first_name[0:2], first_name[2:4])
# Out:
# Ah me

# %%
first_name[-1]
# Out:
# 'd'

# %%
len(first_name)
# Out:
# 5

# %%
#12345[-1]

# %%
'12345'[-1]
# Out:
# '5'

# %%
atom_name = 'carbon'

print(atom_name[1:3])  # ar
print(atom_name[2:4])  # rb
print(atom_name[2:2])  # r? nothing?
print(atom_name[2:-1]) # racn?  rbon?  rbo?
print(atom_name[:-2])  # car?  carb?
print(atom_name[1:99]) # Error?  arbon?
# Out:
# ar
# rb
#
# rbo
# carb
# arbon

# %%
atom_name[99:3:-1]
# Out:
# 'no'

# %%
'carbon'[::-1]
# Out:
# 'nobrac'

# %%
atom_name[0:]
# Out:
# 'carbon'

# %%
a = 12345
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 12345.0

# %%
str(a)
# Out:
# '12345'

# %%
print(a)
print(str(a))
# Out:
# 12345
# 12345

# %%
b = 46
print(type(b))
print(b - 4)
print(b - 4.1)
#print(b - '4.1')
# Out:
# <class 'int'>
# 42
# 41.9

# %%
#'ahmed' - 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-f769cc026727> in <module>()
# ----> 1 'ahmed' - 'd'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
'ahmed' + 'd'
# Out:
# 'ahmedd'

# %%
separator = "*"
print(separator * 12)
# Out:
# ************

# %%
print(5 / 3)  # 1.666667
print(5 // 3) # 1
print(5 % 3)  # 2
# Out:
# 1.6666666666666667
# 1
# 2

# %%
str(1234)
# Out:
# '1234'

# %%
int('1234')
# Out:
# 1234

# %%
int('abcd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-b6487b2c3886> in <module>()
# ----> 1 int('abcd')
#
# ValueError: invalid literal for int() with base 10: 'abcd'

# %%
float(1234)
# Out:
# 1234.0

# %%
float('abcd')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-e68d80576058> in <module>()
# ----> 1 float('abcd')
#
# ValueError: could not convert string to float: 'abcd'

# %%
float('1234')
# Out:
# 1234.0

# %%
4 + 2j
# Out:
# (4+2j)

# %%
4 + 2j + 3 - j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-a066c7b0bca3> in <module>()
# ----> 1 4 + 2j + 3 - j
#
# NameError: name 'j' is not defined

# %%
4 + 2j + 3 - 1j
# Out:
# (7+1j)

# %% [markdown]
# # built-in functions and libraries

# %%
# len, str, float, print, type, int
len('12345', 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-43897ef35a7e> in <module>()
#       1 # len, str, float, print, type, int
# ----> 2 len('12345', 3)
#
# TypeError: len() takes exactly one argument (2 given)

# %%
print("foo")
print()
print('bar')
# Out:
# foo
#
# bar

# %%
len(first_name)
# Out:
# 5

# %%
int('1234')
# Out:
# 1234

# %%
str(1234)
# Out:
# '1234'

# %%
print_returns = print('foo')
# Out:
# foo

# %%
print(print_returns)
# Out:
# None

# %%
type(print_returns)
# Out:
# NoneType

# %%
max(1, 2.1, -3.7)
# Out:
# 2.1

# %%
max('a', 'b', 'c')
# Out:
# 'c'

# %%
max('a', 'B', 'C')
# Out:
# 'a'

# %%
print(ord('B'), ord('a'))
# Out:
# 66 97

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
# ?ord

# %%
round(1234.5678)
# Out:
# 1235

# %%
round(1234.5678, 2)
# Out:
# 1234.57

# %%
round(1234.5678, -2)
# Out:
# 1200.0

# %%
import math

# %%
print('pi is approx.', math.pi)
# Out:
# pi is approx. 3.141592653589793

# %%
math.cos(math.pi)
# Out:
# -1.0

# %%
# ?math.atanh

# %%
import numpy as np

# %%
# np.linalg.<TAB>
# np.random.<TAB>
# np.fft.<TAB>

# %%
from math import pi, cos, sin
print('sin(pi/2) is', sin(pi / 2))
# Out:
# sin(pi/2) is 1.0

# %%
from numpy import fft

# %%
bases = 'ACTTGCTTGAC'

# %%
import random

# %%
# ?random

# %%
random.sample(bases, 1)
# Out:
# ['G']

# %%
bases[random.randint(0, len(bases) - 1)]
# Out:
# 'A'

# %%
bases[math.floor(random.uniform(0, len(bases)))]
# Out:
# 'T'

# %%
# ?random.uniform

# %%
random.choice(bases)
# Out:
# 'T'

# %%
bases[random.randrange(len(bases))]
# Out:
# 'C'

# %%
# ?random

# %%
random.random()
# Out:
# 0.6310740355941425

# %% [markdown]
# # PANDAS!

# %%
import pandas as pd

# %%
data = pd.read_csv('../data/gapminder_gdp_oceania.csv')

# %%
print(data)
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
data = pd.read_csv('../data/gapminder_gdp_oceania.csv', index_col='country')
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.set_index('gdpPercap_1952')
# Out:
#                 gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# gdpPercap_1952
# 10039.59564        10949.64959     12217.22686     14526.12465
# 10556.57566        12247.39532     13175.67800     14463.91893
#
#                 gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# gdpPercap_1952
# 10039.59564        16788.62948     18334.19751     19477.00928
# 10556.57566        16046.03728     16233.71770     17632.41040
#
#                 gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# gdpPercap_1952
# 10039.59564        21888.88903     23424.76683     26997.93657
# 10556.57566        19007.19129     18363.32494     21050.41377
#
#                 gdpPercap_2002  gdpPercap_2007
# gdpPercap_1952
# 10039.59564        30687.75473     34435.36744
# 10556.57566        23189.80135     25185.00911

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
# three different ways to set index:
# 1. in pd.read_csv(..., index_col='column_name')
# 2. data = data.set_index('column_name')
# 3. data.set_index('column_name', inplace=True)

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
data.T
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
data.T.describe()
# Out:
# country     Australia   New Zealand
# count       12.000000     12.000000
# mean     19980.595634  17262.622813
# std       7815.405220   4409.009167
# min      10039.595640  10556.575660
# 25%      13948.900203  14141.858698
# 50%      18905.603395  16933.064050
# 75%      24318.059265  19517.996910
# max      34435.367440  25185.009110

# %%
# if you want to transpose the data permanently:
# data = data.T

# %%
# exercise
# load, describe(), and save the africa data

data_afr = pd.read_csv('../data/gapminder_gdp_africa.csv', index_col='country')
result = data_afr.T.describe()
result.to_csv('africa_summary.csv')

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E06D-15B2
#
#  Directory of C:\Users\Yohan_Min\Desktop\swc-python\demo
#
# 01/19/2019  12:52 AM    <DIR>          .
# 01/19/2019  12:52 AM    <DIR>          ..
# 01/19/2019  12:34 AM    <DIR>          .ipynb_checkpoints
# 01/19/2019  12:52 AM             6,419 africa_summary.csv
# 01/18/2019  04:23 PM               746 summarize_data.py
# 01/19/2019  12:52 AM            71,903 swc_py_day1.ipynb
# 01/18/2019  07:16 PM           371,747 swc_py_day2.ipynb
#                4 File(s)        450,815 bytes
#                3 Dir(s)  356,354,433,024 bytes free

# %%
summary = pd.read_csv('africa_summary.csv', index_col=0)

# %%
summary
# Out:
#            Algeria       Angola        Benin      Botswana  Burkina Faso  \
# count    12.000000    12.000000    12.000000     12.000000     12.000000
# mean   4426.025973  3607.100529  1155.395107   5031.503557    843.990665
# std    1310.337656  1165.900251   159.741306   4178.136987    183.430087
# min    2449.008185  2277.140884   949.499064    851.241141    543.255241
# 25%    3188.737834  2724.676675  1034.163871   1156.945465    738.168283
# 50%    4853.855903  3264.628814  1138.502280   3882.999984    830.967281
# 75%    5386.369921  4401.265373  1244.205873   8127.369312    935.388320
# max    6223.367465  5522.776375  1441.284873  12569.851770   1217.032994
#
#           Burundi     Cameroon  Central African Republic         Chad  \
# count   12.000000    12.000000                 12.000000    12.000000
# mean   471.662990  1774.634222                958.784697  1165.453674
# std     99.329720   419.589901                191.952888   230.548080
# ...

# %%
pd.read_csv('../data/gapminder_gdp_africa.csv', index_col='country').T.describe().to_csv('afr_summary.csv')

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E06D-15B2
#
#  Directory of C:\Users\Yohan_Min\Desktop\swc-python\demo
#
# 01/19/2019  12:53 AM    <DIR>          .
# 01/19/2019  12:53 AM    <DIR>          ..
# 01/19/2019  12:34 AM    <DIR>          .ipynb_checkpoints
# 01/19/2019  12:53 AM             6,419 afr_summary.csv
# 01/19/2019  12:52 AM             6,419 africa_summary.csv
# 01/18/2019  04:23 PM               746 summarize_data.py
# 01/19/2019  12:52 AM            71,903 swc_py_day1.ipynb
# 01/18/2019  07:16 PM           371,747 swc_py_day2.ipynb
#                5 File(s)        457,234 bytes
#                3 Dir(s)  356,353,900,544 bytes free

# %%
eur = pd.read_csv('../data/gapminder_gdp_europe.csv', index_col='country')

# %%
eur
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
eur.shape
# Out:
# (30, 12)

# %%
eur.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
eur.tail()
# Out:
#                 gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Spain              3834.034742     4564.802410     5693.843879
# Sweden             8527.844662     9911.878226    12329.441920
# Switzerland       14734.232750    17909.489730    20431.092700
# Turkey             1969.100980     2218.754257     2322.869908
# United Kingdom     9979.508487    11283.177950    12477.177070
#
#                 gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Spain              7993.512294     10638.75131    13236.921170
# Sweden            15258.296970     17832.02464    18855.725210
# Switzerland       22966.144320     27195.11304    26982.290520
# Turkey             2826.356387      3450.69638     4269.122326
# United Kingdom    14142.850890     15895.11641    17428.748460
#
#                 gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# Spain             13926.169970    15764.983130    18603.064520
# ...

# %%
eur.loc['Albania', 'gdpPercap_1952']
# Out:
# 1601.056136

# %%
eur.iloc[0, 0]
# Out:
# 1601.056136

# %%
# eur[0, 0]

# %%
eur.loc['Albania']
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %%
eur.loc[:, 'gdpPercap_1952']
# Out:
# country
# Albania                    1601.056136
# Austria                    6137.076492
# Belgium                    8343.105127
# Bosnia and Herzegovina      973.533195
# Bulgaria                   2444.286648
# Croatia                    3119.236520
# Czech Republic             6876.140250
# Denmark                    9692.385245
# Finland                    6424.519071
# France                     7029.809327
# Germany                    7144.114393
# Greece                     3530.690067
# Hungary                    5263.673816
# Iceland                    7267.688428
# Ireland                    5210.280328
# Italy                      4931.404155
# Montenegro                 2647.585601
# Netherlands                8941.571858
# Norway                    10095.421720
# Poland                     4029.329699
# Portugal                   3068.319867
# Romania                    3144.613186
# Serbia                     3581.459448
# Slovak Republic            5074.659104
# ...

# %%
eur.iloc[:, 0]
# Out:
# country
# Albania                    1601.056136
# Austria                    6137.076492
# Belgium                    8343.105127
# Bosnia and Herzegovina      973.533195
# Bulgaria                   2444.286648
# Croatia                    3119.236520
# Czech Republic             6876.140250
# Denmark                    9692.385245
# Finland                    6424.519071
# France                     7029.809327
# Germany                    7144.114393
# Greece                     3530.690067
# Hungary                    5263.673816
# Iceland                    7267.688428
# Ireland                    5210.280328
# Italy                      4931.404155
# Montenegro                 2647.585601
# Netherlands                8941.571858
# Norway                    10095.421720
# Poland                     4029.329699
# Portugal                   3068.319867
# Romania                    3144.613186
# Serbia                     3581.459448
# Slovak Republic            5074.659104
# ...

# %%
eur.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
eur['gdpPercap_1962']
# Out:
# country
# Albania                    2312.888958
# Austria                   10750.721110
# Belgium                   10991.206760
# Bosnia and Herzegovina     1709.683679
# Bulgaria                   4254.337839
# Croatia                    5477.890018
# Czech Republic            10136.867130
# Denmark                   13583.313510
# Finland                    9371.842561
# France                    10560.485530
# Germany                   12902.462910
# Greece                     6017.190733
# Hungary                    7550.359877
# Iceland                   10350.159060
# Ireland                    6631.597314
# Italy                      8243.582340
# Montenegro                 4649.593785
# Netherlands               12790.849560
# Norway                    13450.401510
# Poland                     5338.752143
# Portugal                   4727.954889
# Romania                    4734.997586
# Serbia                     6289.629157
# Slovak Republic            7481.107598
# ...

# %%
eur.iloc[0:5, 0:3]
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839

# %%
subset = eur.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']
subset.min()
# Out:
# gdpPercap_1962    4649.593785
# gdpPercap_1967    5907.850937
# gdpPercap_1972    7778.414017
# dtype: float64

# %%
subset
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
# ?subset.min

# %%
subset.min(1)
# Out:
# country
# Italy           8243.582340
# Montenegro      4649.593785
# Netherlands    12790.849560
# Norway         13450.401510
# Poland          5338.752143
# dtype: float64

# %%
subset.min(axis=0)
# Out:
# gdpPercap_1962    4649.593785
# gdpPercap_1967    5907.850937
# gdpPercap_1972    7778.414017
# dtype: float64

# %%
subset > 10000
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %%
subset[subset > 10000]
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                   NaN     10022.40131     12269.27378
# Montenegro              NaN             NaN             NaN
# Netherlands     12790.84956     15363.25136     18794.74567
# Norway          13450.40151     16361.87647     18965.05551
# Poland                  NaN             NaN             NaN

# %%
subset
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
subset[subset > 10000].min()
# Out:
# gdpPercap_1962    12790.84956
# gdpPercap_1967    10022.40131
# gdpPercap_1972    12269.27378
# dtype: float64

# %%
subset[subset > 10000].min(axis=1)
# Out:
# country
# Italy          10022.40131
# Montenegro             NaN
# Netherlands    12790.84956
# Norway         13450.40151
# Poland                 NaN
# dtype: float64

# %%
subset[subset > 10000].describe()
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        2.000000        3.000000        3.000000
# mean     13120.625535    13915.843047    16676.358320
# std        466.373656     3408.589070     3817.597015
# min      12790.849560    10022.401310    12269.273780
# 25%      12955.737547    12692.826335    15532.009725
# 50%      13120.625535    15363.251360    18794.745670
# 75%      13285.513523    15862.563915    18879.900590
# max      13450.401510    16361.876470    18965.055510

# %%
eur.loc['Italy':'Poland']
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy           4931.404155     6248.656232     8243.582340    10022.401310
# Montenegro      2647.585601     3682.259903     4649.593785     5907.850937
# Netherlands     8941.571858    11276.193440    12790.849560    15363.251360
# Norway         10095.421720    11653.973040    13450.401510    16361.876470
# Poland          4029.329699     4734.253019     5338.752143     6557.152776
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Italy          12269.273780    14255.984750    16537.483500    19207.234820
# Montenegro      7778.414017     9595.929905    11222.587620    11732.510170
# Netherlands    18794.745670    21209.059200    21399.460460    23651.323610
# Norway         18965.055510    23311.349390    26298.635310    31540.974800
# Poland          8006.506993     9508.141454     8451.531004     9082.351172
#
# ...

# %%
eur.loc['Italy':'Poland', :]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Italy           4931.404155     6248.656232     8243.582340    10022.401310
# Montenegro      2647.585601     3682.259903     4649.593785     5907.850937
# Netherlands     8941.571858    11276.193440    12790.849560    15363.251360
# Norway         10095.421720    11653.973040    13450.401510    16361.876470
# Poland          4029.329699     4734.253019     5338.752143     6557.152776
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Italy          12269.273780    14255.984750    16537.483500    19207.234820
# Montenegro      7778.414017     9595.929905    11222.587620    11732.510170
# Netherlands    18794.745670    21209.059200    21399.460460    23651.323610
# Norway         18965.055510    23311.349390    26298.635310    31540.974800
# Poland          8006.506993     9508.141454     8451.531004     9082.351172
#
# ...

# %%
eur.index
# Out:
# Index(['Albania', 'Austria', 'Belgium', 'Bosnia and Herzegovina', 'Bulgaria',
#        'Croatia', 'Czech Republic', 'Denmark', 'Finland', 'France', 'Germany',
#        'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Montenegro',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia',
#        'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#        'Turkey', 'United Kingdom'],
#       dtype='object', name='country')

# %%
eur.index.tolist()
# Out:
# ['Albania',
#  'Austria',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Montenegro',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Serbia',
#  'Slovak Republic',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Turkey',
#  'United Kingdom']

# %%
scrambled = eur.loc[random.sample(eur.index.tolist(), len(eur.index))]

# %%
scrambled
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Poland                     4029.329699     4734.253019     5338.752143
# Turkey                     1969.100980     2218.754257     2322.869908
# United Kingdom             9979.508487    11283.177950    12477.177070
# Greece                     3530.690067     4916.299889     6017.190733
# Serbia                     3581.459448     4981.090891     6289.629157
# Italy                      4931.404155     6248.656232     8243.582340
# Denmark                    9692.385245    11099.659350    13583.313510
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Iceland                    7267.688428     9244.001412    10350.159060
# Romania                    3144.613186     3943.370225     4734.997586
# Croatia                    3119.236520     4338.231617     5477.890018
# Norway                    10095.421720    11653.973040    13450.401510
# ...

# %%
scrambled.loc['Italy':'Poland']
# Out:
# Empty DataFrame
# Columns: [gdpPercap_1952, gdpPercap_1957, gdpPercap_1962, gdpPercap_1967, gdpPercap_1972, gdpPercap_1977, gdpPercap_1982, gdpPercap_1987, gdpPercap_1992, gdpPercap_1997, gdpPercap_2002, gdpPercap_2007]
# Index: []

# %%
scrambled.sort_index(inplace=True)

# %%
scrambled
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
print(eur.shape, eur.mean().shape)
# Out:
# (30, 12) (12,)

# %%
eur.mean()
# Out:
# gdpPercap_1952     5661.057435
# gdpPercap_1957     6963.012816
# gdpPercap_1962     8365.486814
# gdpPercap_1967    10143.823757
# gdpPercap_1972    12479.575246
# gdpPercap_1977    14283.979110
# gdpPercap_1982    15617.896551
# gdpPercap_1987    17214.310727
# gdpPercap_1992    17061.568084
# gdpPercap_1997    19076.781802
# gdpPercap_2002    21711.732422
# gdpPercap_2007    25054.481636
# dtype: float64

# %%
mask = eur > eur.mean()

# %%
mask
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
# Croatia                          False           False           False
# Czech Republic                    True            True            True
# Denmark                           True            True            True
# Finland                           True            True            True
# France                            True            True            True
# Germany                           True            True            True
# Greece                           False           False           False
# ...

# %%
wealth_index = mask.sum(axis=1)

# %%
mask.sum(axis=1)
# Out:
# country
# Albania                    0
# Austria                   12
# Belgium                   12
# Bosnia and Herzegovina     0
# Bulgaria                   0
# Croatia                    0
# Czech Republic             6
# Denmark                   12
# Finland                   12
# France                    12
# Germany                   12
# Greece                     4
# Hungary                    0
# Iceland                   12
# Ireland                    4
# Italy                      6
# Montenegro                 0
# Netherlands               12
# Norway                    12
# Poland                     0
# Portugal                   0
# Romania                    0
# Serbia                     0
# Slovak Republic            0
# Slovenia                   4
# Spain                      4
# Sweden                    12
# Switzerland               12
# Turkey                     0
# United Kingdom            12
# dtype: int64

# %%
wealth_index[wealth_index > 0]
# Out:
# country
# Austria           12
# Belgium           12
# Czech Republic     6
# Denmark           12
# Finland           12
# France            12
# Germany           12
# Greece             4
# Iceland           12
# Ireland            4
# Italy              6
# Netherlands       12
# Norway            12
# Slovenia           4
# Spain              4
# Sweden            12
# Switzerland       12
# United Kingdom    12
# dtype: int64

# %%
wealth_index
# Out:
# country
# Albania                    0
# Austria                   12
# Belgium                   12
# Bosnia and Herzegovina     0
# Bulgaria                   0
# Croatia                    0
# Czech Republic             6
# Denmark                   12
# Finland                   12
# France                    12
# Germany                   12
# Greece                     4
# Hungary                    0
# Iceland                   12
# Ireland                    4
# Italy                      6
# Montenegro                 0
# Netherlands               12
# Norway                    12
# Poland                     0
# Portugal                   0
# Romania                    0
# Serbia                     0
# Slovak Republic            0
# Slovenia                   4
# Spain                      4
# Sweden                    12
# Switzerland               12
# Turkey                     0
# United Kingdom            12
# dtype: int64

# %% [markdown]
# # ??

# %%
eur.groupby(wealth_index).sum()
# Out:
#     gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0     36916.854200    46110.918793    56850.065437    71324.848786
# 4     16790.046878    20942.456800    25744.935321    33567.667670
# 6     11807.544405    14505.000150    18380.449470    21421.846200
# 12   104317.277560   127332.008735   149989.154201   178000.350040
#
#     gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0     88569.346898   104459.358438   113553.768507   119649.599409
# 4     45277.839976    53860.456750    59679.634020    64436.912960
# 6     25377.727380    29056.145370    31914.712050    35517.678220
# 12   215162.343140   241143.412730   263388.781960   296825.131210
#
#     gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# 0     92380.047256   103772.937598   118590.929863   149577.357928
# 4     67918.093220    80876.051580   102086.795210   122803.729520
# 6     36310.666080    40723.538700    45564.308390    51403.028210
# ...

# %%
data_all = pd.read_csv('../data/gapminder_all.csv', index_col='country')

# %%
data_all.head()
# Out:
#              continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria         Africa     2449.008185     3013.976023     2550.816880
# Angola          Africa     3520.610273     3827.940465     4269.276742
# Benin           Africa     1062.752200      959.601080      949.499064
# Botswana        Africa      851.241141      918.232535      983.653976
# Burkina Faso    Africa      543.255241      617.183465      722.512021
#
#               gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Algeria          3246.991771     4182.663766     4910.416756     5745.160213
# Angola           5522.776375     5473.288005     3008.647355     2756.953672
# Benin            1035.831411     1085.796879     1029.161251     1277.897616
# Botswana         1214.709294     2263.611114     3214.857818     4551.142150
# Burkina Faso      794.826560      854.735976      743.387037      807.198586
#
# ...

# %%
data_all.columns
# Out:
# Index(['continent', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007', 'lifeExp_1952', 'lifeExp_1957', 'lifeExp_1962',
#        'lifeExp_1967', 'lifeExp_1972', 'lifeExp_1977', 'lifeExp_1982',
#        'lifeExp_1987', 'lifeExp_1992', 'lifeExp_1997', 'lifeExp_2002',
#        'lifeExp_2007', 'pop_1952', 'pop_1957', 'pop_1962', 'pop_1967',
#        'pop_1972', 'pop_1977', 'pop_1982', 'pop_1987', 'pop_1992', 'pop_1997',
#        'pop_2002', 'pop_2007'],
#       dtype='object')

# %%
data_all['continent']
# Out:
# country
# Algeria                      Africa
# Angola                       Africa
# Benin                        Africa
# Botswana                     Africa
# Burkina Faso                 Africa
# Burundi                      Africa
# Cameroon                     Africa
# Central African Republic     Africa
# Chad                         Africa
# Comoros                      Africa
# Congo Dem. Rep.              Africa
# Congo Rep.                   Africa
# Cote d'Ivoire                Africa
# Djibouti                     Africa
# Egypt                        Africa
# Equatorial Guinea            Africa
# Eritrea                      Africa
# Ethiopia                     Africa
# Gabon                        Africa
# Gambia                       Africa
# Ghana                        Africa
# Guinea                       Africa
# Guinea-Bissau                Africa
# Kenya                        Africa
# Lesotho                      Africa
# Liberia                      Africa
# ...

# %%
americas = data_all[data_all['continent'] == 'Americas']

# %%
americas.shape
# Out:
# (25, 37)

# %%
data_all.shape
# Out:
# (142, 37)

# %%
data_all['continent'] == 'Americas'
# Out:
# country
# Algeria                     False
# Angola                      False
# Benin                       False
# Botswana                    False
# Burkina Faso                False
# Burundi                     False
# Cameroon                    False
# Central African Republic    False
# Chad                        False
# Comoros                     False
# Congo Dem. Rep.             False
# Congo Rep.                  False
# Cote d'Ivoire               False
# Djibouti                    False
# Egypt                       False
# Equatorial Guinea           False
# Eritrea                     False
# Ethiopia                    False
# Gabon                       False
# Gambia                      False
# Ghana                       False
# Guinea                      False
# Guinea-Bissau               False
# Kenya                       False
# Lesotho                     False
# Liberia                     False
# Libya                       False
# ...

# %%
americas = data_all[data_all['continent'] == 'Americas']
americas = americas.drop("Puerto Rico", axis=0)
americas = americas.drop('continent', axis=1)

# %%
americas = data_all[data_all['continent'] == 'Americas']

# %%
americas = americas.drop("Puerto Rico", axis=0)

# %%
americas
# Out:
#                      gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina               5911.315053     6856.856212     7133.166023
# Bolivia                 2677.326347     2127.686326     2180.972546
# Brazil                  2108.944355     2487.365989     3336.585802
# Canada                 11367.161120    12489.950060    13462.485550
# Chile                   3939.978789     4315.622723     4519.094331
# Colombia                2144.115096     2323.805581     2492.351109
# Costa Rica              2627.009471     2990.010802     3460.937025
# Cuba                    5586.538780     6092.174359     5180.755910
# Dominican Republic      1397.717137     1544.402995     1662.137359
# Ecuador                 3522.110717     3780.546651     4086.114078
# El Salvador             3048.302900     3421.523218     3776.803627
# Guatemala               2428.237769     2617.155967     2750.364446
# Haiti                   1840.366939     1726.887882     1796.589032
# ...
